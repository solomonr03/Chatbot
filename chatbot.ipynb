# %%
#SOURCE: https://pytorch.org/tutorials/beginner/chatbot_tutorial.html?highlight=chatbot
# and put in a ``data/`` directory under the current directory.
#
# After that, let’s import some necessities.
#

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json
from google.colab import drive
drive.mount('/content/gdrive')


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")
# Out:
# Mounted at /content/gdrive

# %%
corpus_name = "movie-corpus"
corpus = os.path.join("/content/gdrive/MyDrive/data", corpus_name)

def printLines(file, n=6):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "utterances.jsonl"))
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'

# %%
def lines_and_conversations(fileName):
  lines = {}
  conversations = {}
  with open(fileName, 'r', encoding='iso-8859-1') as f:
    #Parse the loaded data and create our line and conversation dictionaries
    for line in f:
      lineJson = json.loads(line)
      lineObj = {}
      lineObj["lineID"] = lineJson["id"]
      lineObj["charID"] = lineJson["speaker"]
      lineObj["sen"] = lineJson["text"]
      lines[lineJson["id"]] = lineObj

      if lineJson["conversation_id"] not in conversations:
        convObj = {}
        convObj["convID"] = lineJson["conversation_id"]
        convObj["movieID"] = lineJson["meta"]["movie_id"]
        convObj["lines"] = [lineObj]
      else:
        convObj = conversations[lineJson["conversation_id"]]
        convObj["lines"].insert(0,lineObj)
      conversations[lineJson["conversation_id"]] = convObj
  return line, conversations

def get_sentences_pairs(conversations):
  pairs = []
  for conv in conversations.values():
    for i in range(len(conv["lines"])-1):
      input = conv["lines"][i]["sen"].strip()
      target = conv["lines"][i+1]["sen"].strip()
      if input and target:
        pairs.append([input, target])
  return pairs

datafile = os.path.join(corpus, "formatted_lines.txt")

delimiter = str(codecs.decode('\t', "unicode_escape"))

lines = {}
conversations = {}

lines, conversations = lines_and_conversations(os.path.join(corpus, "utterances.jsonl"))

with open(datafile, 'w', encoding='utf-8') as outputfile:
  writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
  for pair in get_sentences_pairs(conversations):
    writer.writerow(pair)

printLines(datafile)
# Out:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"

# %%
#Create a vocabulary that maps words to a discrete numerical space

PAD_token = 0 # Padding to maintain shape
SOS_token = 1 # Start of sentence token
EOS_token = 2 # End of sentence token

class Voc:
  def __init__(self, name):
    self.name = name
    self.trimmed = False
    self.word2index = {}
    self.word2count = {}
    self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
    self.num_words = 3

  def addWord(self, word):
    if word not in self.word2index:
      self.word2index[word] = self.num_words
      self.word2count[word] = 1
      self.index2word[self.num_words] = word
      self.num_words += 1
    else:
      self.word2count[word] += 1

  def addSentence(self, sen):
    for word in sen.split(' '):
      self.addWord(word)

  def trim(self, min_count):
    if self.trimmed:
      return

    self.trimmed = True

    keep_words = []

    for k, v in self.word2count.items():
      if v >= min_count:
        keep_words.append(k)

    print('keep_words {} / {} = {:.4f}'.format(len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)))

    self.word2index = {}
    self.word2count = {}
    self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
    self.num_words = 3

    for word in keep_words:
      self.addWord(word)

# %%
#Convert unicode strings to ascii and normalize sentences
#Filter long sentences to help with training

MAX_LEN = 10

def unicode2ascii(s):
  return ''.join(
      c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c)
  )

def normalizeString(s):
  s = unicode2ascii(s.lower().strip())
  s = re.sub(r"([.!>])", r"\1", s)
  s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
  s = re.sub(r"\s+", r" ", s).strip()
  return s

def readVocs(datafile, corpus_name):
  lines = open(datafile, encoding='utf-8').read().strip().split('\n')
  pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
  voc = Voc(corpus_name)
  return voc, pairs

def filterPair(p):
  return len(p[0].split(' ')) < MAX_LEN and len(p[1].split(' ')) < MAX_LEN

def filterPairs(pairs):
  return [pair for pair in pairs if filterPair(pair)]

def loadPrepareData(corpus, corpus_name, datfile, save_dir):
  voc, pairs = readVocs(datafile, corpus_name)
  pairs = filterPairs(pairs)
  for pair in pairs:
    voc.addSentence(pair[0])
    voc.addSentence(pair[1])
  return voc, pairs

save_dir = os.path.join("/content/gdrive/MyDrive/data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)

# %%
#Trim rarely used words out of vocabulary for faster convergence during training
#Decrease feature space to help the difficulty of the function the model will learn


MIN_COUNT = 3

def trimRareWords(voc, pairs, MIN_COUNT):
  voc.trim(MIN_COUNT)
  keep_pairs = []
  for pair in pairs:
    input_sentence = pair[0]
    output_sentence = pair[1]
    keep_input = True
    keep_output = True
    for word in input_sentence.split(' '):
      if word not in voc.word2index:
        keep_input = False
        break
    for word in output_sentence.split(' '):
      if word not in voc.word2index:
        keep_output = False
        break
    if keep_input and keep_output:
      keep_pairs.append(pair)

  print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
  return keep_pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 14666 / 41924 = 0.3498
# Trimmed from 84136 pairs to 57089, 0.6785 of total

# %%
#Prepare data for model by putting it into minibatches

def indexesFromSentence(voc, sentence):
  return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]

def zeroPadding(l, fillvalue=PAD_token):
  return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
  m = []
  for i, seq in enumerate(l):
    m.append([])
    for token in seq:
      if token == PAD_token:
        m[i].append(0)
      else:
        m[i].append(1)
  return m

def inputVar(l, voc):
  indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
  lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
  padList = zeroPadding(indexes_batch)
  padVar = torch.LongTensor(padList)
  return padVar, lengths

def outputVar(l, voc):
  indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
  lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
  max_target_len = max([len(indexes) for indexes in indexes_batch])
  padList = zeroPadding(indexes_batch)
  padVar = torch.LongTensor(padList)
  return padVar, lengths, max_target_len

def batch2TrainData(voc, pair_batch):
  pair_batch.sort(key=lambda x:len(x[0].split(" ")), reverse=True)
  input_batch, output_batch = [], []
  for pair in pair_batch:
    input_batch.append(pair[0])
    output_batch.append(pair[1])
  inp, lengths = inputVar(input_batch, voc)
  output, mask, max_target_len = outputVar(output_batch, voc)
  return inp, lengths, output, mask, max_target_len

small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[ 581,  112,  108,   67, 8799],
#         [  21,   77,   14,    2,    2],
#         [  64,   19,  118,    0,    0],
#         [ 572, 1216, 1107,    0,    0],
#         [4229,  735,    2,    0,    0],
#         [  29,    2,    0,    0,    0],
#         [4230,    0,    0,    0,    0],
#         [1201,    0,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([9, 6, 5, 2, 2])
# target_variable: tensor([[   9,  454,   16, 3421,  190],
#         [4231,  425, 1107, 2811,  169],
#         [   2,    2,    2,   14,   21],
#         [   0,    0,    0, 3545,   36],
#         [   0,    0,    0,    2,  479],
#         [   0,    0,    0,    0,    2]])
# mask: tensor([3, 3, 3, 5, 6])
# max_target_len: 6

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size parameters are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask.type(torch.bool)).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LEN):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LEN):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000


# Load model if a ``loadFilename`` is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have CUDA, configure CUDA to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 9.6080
# Iteration: 2; Percent complete: 0.1%; Average loss: 9.2135
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6826
# Iteration: 4; Percent complete: 0.1%; Average loss: 7.8154
# Iteration: 5; Percent complete: 0.1%; Average loss: 7.2430
# Iteration: 6; Percent complete: 0.1%; Average loss: 6.4785
# Iteration: 7; Percent complete: 0.2%; Average loss: 5.7574
# Iteration: 8; Percent complete: 0.2%; Average loss: 5.3082
# Iteration: 9; Percent complete: 0.2%; Average loss: 5.0117
# Iteration: 10; Percent complete: 0.2%; Average loss: 5.2850
# Iteration: 11; Percent complete: 0.3%; Average loss: 5.7024
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.3769
# Iteration: 13; Percent complete: 0.3%; Average loss: 4.5217
# Iteration: 14; Percent complete: 0.4%; Average loss: 4.3712
# Iteration: 15; Percent complete: 0.4%; Average loss: 4.5010
# Iteration: 16; Percent complete: 0.4%; Average loss: 3.5977
# Iteration: 17; Percent complete: 0.4%; Average loss: 4.0928
# Iteration: 18; Percent complete: 0.4%; Average loss: 4.1462
# Iteration: 19; Percent complete: 0.5%; Average loss: 3.7635
# Iteration: 20; Percent complete: 0.5%; Average loss: 3.5631
# Iteration: 21; Percent complete: 0.5%; Average loss: 3.2114
# Iteration: 22; Percent complete: 0.5%; Average loss: 3.0119
# Iteration: 23; Percent complete: 0.6%; Average loss: 3.4153
# Iteration: 24; Percent complete: 0.6%; Average loss: 3.6869
# Iteration: 25; Percent complete: 0.6%; Average loss: 3.6183
# Iteration: 26; Percent complete: 0.7%; Average loss: 3.7894
# Iteration: 27; Percent complete: 0.7%; Average loss: 3.0089
# Iteration: 28; Percent complete: 0.7%; Average loss: 3.1725
# Iteration: 29; Percent complete: 0.7%; Average loss: 3.7678
# Iteration: 30; Percent complete: 0.8%; Average loss: 3.4523
# Iteration: 31; Percent complete: 0.8%; Average loss: 3.9420
# Iteration: 32; Percent complete: 0.8%; Average loss: 3.2594
# Iteration: 33; Percent complete: 0.8%; Average loss: 3.5081
# Iteration: 34; Percent complete: 0.9%; Average loss: 3.6552
# Iteration: 35; Percent complete: 0.9%; Average loss: 3.2848
# Iteration: 36; Percent complete: 0.9%; Average loss: 3.1497
# Iteration: 37; Percent complete: 0.9%; Average loss: 2.8667
# Iteration: 38; Percent complete: 0.9%; Average loss: 3.8382
# Iteration: 39; Percent complete: 1.0%; Average loss: 3.4664
# Iteration: 40; Percent complete: 1.0%; Average loss: 3.0092
# Iteration: 41; Percent complete: 1.0%; Average loss: 2.8033
# Iteration: 42; Percent complete: 1.1%; Average loss: 3.4880
# Iteration: 43; Percent complete: 1.1%; Average loss: 3.1515
# Iteration: 44; Percent complete: 1.1%; Average loss: 3.3909
# Iteration: 45; Percent complete: 1.1%; Average loss: 2.8180
# Iteration: 46; Percent complete: 1.1%; Average loss: 2.9752
# Iteration: 47; Percent complete: 1.2%; Average loss: 3.5107
# Iteration: 48; Percent complete: 1.2%; Average loss: 2.5096
# Iteration: 49; Percent complete: 1.2%; Average loss: 3.2786
# Iteration: 50; Percent complete: 1.2%; Average loss: 2.6924
# Iteration: 51; Percent complete: 1.3%; Average loss: 3.2347
# Iteration: 52; Percent complete: 1.3%; Average loss: 3.1347
# Iteration: 53; Percent complete: 1.3%; Average loss: 2.8557
# Iteration: 54; Percent complete: 1.4%; Average loss: 3.3850
# Iteration: 55; Percent complete: 1.4%; Average loss: 3.0293
# Iteration: 56; Percent complete: 1.4%; Average loss: 2.8975
# Iteration: 57; Percent complete: 1.4%; Average loss: 3.2038
# Iteration: 58; Percent complete: 1.5%; Average loss: 3.6535
# Iteration: 59; Percent complete: 1.5%; Average loss: 3.2821
# Iteration: 60; Percent complete: 1.5%; Average loss: 3.2397
# Iteration: 61; Percent complete: 1.5%; Average loss: 3.3632
# Iteration: 62; Percent complete: 1.6%; Average loss: 3.2142
# Iteration: 63; Percent complete: 1.6%; Average loss: 3.2560
# Iteration: 64; Percent complete: 1.6%; Average loss: 3.9901
# Iteration: 65; Percent complete: 1.6%; Average loss: 3.1843
# Iteration: 66; Percent complete: 1.7%; Average loss: 3.0693
# Iteration: 67; Percent complete: 1.7%; Average loss: 3.5131
# Iteration: 68; Percent complete: 1.7%; Average loss: 3.1211
# Iteration: 69; Percent complete: 1.7%; Average loss: 3.6351
# Iteration: 70; Percent complete: 1.8%; Average loss: 2.7946
# Iteration: 71; Percent complete: 1.8%; Average loss: 2.5423
# Iteration: 72; Percent complete: 1.8%; Average loss: 2.9339
# Iteration: 73; Percent complete: 1.8%; Average loss: 3.4131
# Iteration: 74; Percent complete: 1.8%; Average loss: 3.3544
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.0154
# Iteration: 76; Percent complete: 1.9%; Average loss: 3.7323
# Iteration: 77; Percent complete: 1.9%; Average loss: 3.2333
# Iteration: 78; Percent complete: 1.9%; Average loss: 3.3732
# Iteration: 79; Percent complete: 2.0%; Average loss: 3.9250
# Iteration: 80; Percent complete: 2.0%; Average loss: 3.3551
# Iteration: 81; Percent complete: 2.0%; Average loss: 2.4886
# Iteration: 82; Percent complete: 2.1%; Average loss: 3.1885
# Iteration: 83; Percent complete: 2.1%; Average loss: 3.7418
# Iteration: 84; Percent complete: 2.1%; Average loss: 3.2902
# Iteration: 85; Percent complete: 2.1%; Average loss: 3.2678
# Iteration: 86; Percent complete: 2.1%; Average loss: 2.9611
# Iteration: 87; Percent complete: 2.2%; Average loss: 3.3728
# Iteration: 88; Percent complete: 2.2%; Average loss: 3.3023
# Iteration: 89; Percent complete: 2.2%; Average loss: 3.3614
# Iteration: 90; Percent complete: 2.2%; Average loss: 3.1885
# Iteration: 91; Percent complete: 2.3%; Average loss: 3.5100
# Iteration: 92; Percent complete: 2.3%; Average loss: 3.1291
# Iteration: 93; Percent complete: 2.3%; Average loss: 2.8624
# Iteration: 94; Percent complete: 2.4%; Average loss: 3.2611
# Iteration: 95; Percent complete: 2.4%; Average loss: 3.3161
# Iteration: 96; Percent complete: 2.4%; Average loss: 3.2239
# Iteration: 97; Percent complete: 2.4%; Average loss: 2.9303
# Iteration: 98; Percent complete: 2.5%; Average loss: 2.9996
# Iteration: 99; Percent complete: 2.5%; Average loss: 2.7336
# Iteration: 100; Percent complete: 2.5%; Average loss: 2.9588
# Iteration: 101; Percent complete: 2.5%; Average loss: 2.2377
# Iteration: 102; Percent complete: 2.5%; Average loss: 2.7437
# Iteration: 103; Percent complete: 2.6%; Average loss: 3.4911
# Iteration: 104; Percent complete: 2.6%; Average loss: 3.2529
# Iteration: 105; Percent complete: 2.6%; Average loss: 3.2390
# Iteration: 106; Percent complete: 2.6%; Average loss: 2.5196
# Iteration: 107; Percent complete: 2.7%; Average loss: 3.8634
# Iteration: 108; Percent complete: 2.7%; Average loss: 2.7987
# Iteration: 109; Percent complete: 2.7%; Average loss: 2.6974
# Iteration: 110; Percent complete: 2.8%; Average loss: 3.1744
# Iteration: 111; Percent complete: 2.8%; Average loss: 2.8803
# Iteration: 112; Percent complete: 2.8%; Average loss: 2.9876
# Iteration: 113; Percent complete: 2.8%; Average loss: 3.2679
# Iteration: 114; Percent complete: 2.9%; Average loss: 3.1242
# Iteration: 115; Percent complete: 2.9%; Average loss: 2.7056
# Iteration: 116; Percent complete: 2.9%; Average loss: 3.1079
# Iteration: 117; Percent complete: 2.9%; Average loss: 3.7251
# Iteration: 118; Percent complete: 2.9%; Average loss: 2.8622
# Iteration: 119; Percent complete: 3.0%; Average loss: 2.7423
# Iteration: 120; Percent complete: 3.0%; Average loss: 2.9702
# Iteration: 121; Percent complete: 3.0%; Average loss: 3.5107
# Iteration: 122; Percent complete: 3.0%; Average loss: 2.7540
# Iteration: 123; Percent complete: 3.1%; Average loss: 3.4600
# Iteration: 124; Percent complete: 3.1%; Average loss: 3.0341
# Iteration: 125; Percent complete: 3.1%; Average loss: 3.0073
# Iteration: 126; Percent complete: 3.1%; Average loss: 3.1403
# Iteration: 127; Percent complete: 3.2%; Average loss: 2.3602
# Iteration: 128; Percent complete: 3.2%; Average loss: 3.1697
# Iteration: 129; Percent complete: 3.2%; Average loss: 2.9936
# Iteration: 130; Percent complete: 3.2%; Average loss: 3.6363
# Iteration: 131; Percent complete: 3.3%; Average loss: 3.1568
# Iteration: 132; Percent complete: 3.3%; Average loss: 2.4416
# Iteration: 133; Percent complete: 3.3%; Average loss: 2.6592
# Iteration: 134; Percent complete: 3.4%; Average loss: 3.0945
# Iteration: 135; Percent complete: 3.4%; Average loss: 2.9785
# Iteration: 136; Percent complete: 3.4%; Average loss: 2.8090
# Iteration: 137; Percent complete: 3.4%; Average loss: 3.2099
# Iteration: 138; Percent complete: 3.5%; Average loss: 2.7963
# Iteration: 139; Percent complete: 3.5%; Average loss: 2.9009
# Iteration: 140; Percent complete: 3.5%; Average loss: 3.3292
# Iteration: 141; Percent complete: 3.5%; Average loss: 2.9608
# Iteration: 142; Percent complete: 3.5%; Average loss: 3.1799
# Iteration: 143; Percent complete: 3.6%; Average loss: 2.6775
# Iteration: 144; Percent complete: 3.6%; Average loss: 3.1802
# Iteration: 145; Percent complete: 3.6%; Average loss: 3.3398
# Iteration: 146; Percent complete: 3.6%; Average loss: 2.7860
# Iteration: 147; Percent complete: 3.7%; Average loss: 3.7491
# Iteration: 148; Percent complete: 3.7%; Average loss: 2.5332
# Iteration: 149; Percent complete: 3.7%; Average loss: 3.0556
# Iteration: 150; Percent complete: 3.8%; Average loss: 3.0720
# Iteration: 151; Percent complete: 3.8%; Average loss: 3.8975
# Iteration: 152; Percent complete: 3.8%; Average loss: 2.8156
# Iteration: 153; Percent complete: 3.8%; Average loss: 2.6521
# Iteration: 154; Percent complete: 3.9%; Average loss: 3.2284
# Iteration: 155; Percent complete: 3.9%; Average loss: 2.5760
# Iteration: 156; Percent complete: 3.9%; Average loss: 2.5183
# Iteration: 157; Percent complete: 3.9%; Average loss: 2.7205
# Iteration: 158; Percent complete: 4.0%; Average loss: 3.0183
# Iteration: 159; Percent complete: 4.0%; Average loss: 2.8527
# Iteration: 160; Percent complete: 4.0%; Average loss: 2.7802
# Iteration: 161; Percent complete: 4.0%; Average loss: 3.3009
# Iteration: 162; Percent complete: 4.0%; Average loss: 2.9515
# Iteration: 163; Percent complete: 4.1%; Average loss: 2.8808
# Iteration: 164; Percent complete: 4.1%; Average loss: 3.3327
# Iteration: 165; Percent complete: 4.1%; Average loss: 3.1007
# Iteration: 166; Percent complete: 4.2%; Average loss: 2.8800
# Iteration: 167; Percent complete: 4.2%; Average loss: 3.5150
# Iteration: 168; Percent complete: 4.2%; Average loss: 2.9703
# Iteration: 169; Percent complete: 4.2%; Average loss: 3.2225
# Iteration: 170; Percent complete: 4.2%; Average loss: 3.1012
# Iteration: 171; Percent complete: 4.3%; Average loss: 2.2794
# Iteration: 172; Percent complete: 4.3%; Average loss: 3.7347
# Iteration: 173; Percent complete: 4.3%; Average loss: 2.9134
# Iteration: 174; Percent complete: 4.3%; Average loss: 3.1312
# Iteration: 175; Percent complete: 4.4%; Average loss: 2.9749
# Iteration: 176; Percent complete: 4.4%; Average loss: 2.5142
# Iteration: 177; Percent complete: 4.4%; Average loss: 3.1592
# Iteration: 178; Percent complete: 4.5%; Average loss: 2.8814
# Iteration: 179; Percent complete: 4.5%; Average loss: 2.5196
# Iteration: 180; Percent complete: 4.5%; Average loss: 2.7168
# Iteration: 181; Percent complete: 4.5%; Average loss: 3.2259
# Iteration: 182; Percent complete: 4.5%; Average loss: 3.0678
# Iteration: 183; Percent complete: 4.6%; Average loss: 3.0646
# Iteration: 184; Percent complete: 4.6%; Average loss: 3.0321
# Iteration: 185; Percent complete: 4.6%; Average loss: 2.8877
# Iteration: 186; Percent complete: 4.7%; Average loss: 2.3059
# Iteration: 187; Percent complete: 4.7%; Average loss: 2.7651
# Iteration: 188; Percent complete: 4.7%; Average loss: 2.9292
# Iteration: 189; Percent complete: 4.7%; Average loss: 3.4673
# Iteration: 190; Percent complete: 4.8%; Average loss: 3.2632
# Iteration: 191; Percent complete: 4.8%; Average loss: 2.9566
# Iteration: 192; Percent complete: 4.8%; Average loss: 2.4358
# Iteration: 193; Percent complete: 4.8%; Average loss: 3.1348
# Iteration: 194; Percent complete: 4.9%; Average loss: 2.8621
# Iteration: 195; Percent complete: 4.9%; Average loss: 3.0559
# Iteration: 196; Percent complete: 4.9%; Average loss: 2.2475
# Iteration: 197; Percent complete: 4.9%; Average loss: 2.7279
# Iteration: 198; Percent complete: 5.0%; Average loss: 3.4084
# Iteration: 199; Percent complete: 5.0%; Average loss: 2.8014
# Iteration: 200; Percent complete: 5.0%; Average loss: 3.4010
# Iteration: 201; Percent complete: 5.0%; Average loss: 2.3805
# Iteration: 202; Percent complete: 5.1%; Average loss: 2.6126
# Iteration: 203; Percent complete: 5.1%; Average loss: 3.1828
# Iteration: 204; Percent complete: 5.1%; Average loss: 3.0017
# Iteration: 205; Percent complete: 5.1%; Average loss: 2.4450
# Iteration: 206; Percent complete: 5.1%; Average loss: 2.8617
# Iteration: 207; Percent complete: 5.2%; Average loss: 2.9723
# Iteration: 208; Percent complete: 5.2%; Average loss: 2.9655
# Iteration: 209; Percent complete: 5.2%; Average loss: 2.3711
# Iteration: 210; Percent complete: 5.2%; Average loss: 2.9797
# Iteration: 211; Percent complete: 5.3%; Average loss: 2.3200
# Iteration: 212; Percent complete: 5.3%; Average loss: 3.0448
# Iteration: 213; Percent complete: 5.3%; Average loss: 2.6610
# Iteration: 214; Percent complete: 5.3%; Average loss: 2.7765
# Iteration: 215; Percent complete: 5.4%; Average loss: 3.1894
# Iteration: 216; Percent complete: 5.4%; Average loss: 2.8432
# Iteration: 217; Percent complete: 5.4%; Average loss: 2.6907
# Iteration: 218; Percent complete: 5.5%; Average loss: 2.8187
# Iteration: 219; Percent complete: 5.5%; Average loss: 3.1019
# Iteration: 220; Percent complete: 5.5%; Average loss: 2.8040
# Iteration: 221; Percent complete: 5.5%; Average loss: 1.9944
# Iteration: 222; Percent complete: 5.5%; Average loss: 2.6160
# Iteration: 223; Percent complete: 5.6%; Average loss: 3.2602
# Iteration: 224; Percent complete: 5.6%; Average loss: 2.6258
# Iteration: 225; Percent complete: 5.6%; Average loss: 2.6820
# Iteration: 226; Percent complete: 5.7%; Average loss: 1.9495
# Iteration: 227; Percent complete: 5.7%; Average loss: 2.7170
# Iteration: 228; Percent complete: 5.7%; Average loss: 2.5640
# Iteration: 229; Percent complete: 5.7%; Average loss: 3.0433
# Iteration: 230; Percent complete: 5.8%; Average loss: 2.9233
# Iteration: 231; Percent complete: 5.8%; Average loss: 3.4577
# Iteration: 232; Percent complete: 5.8%; Average loss: 2.7115
# Iteration: 233; Percent complete: 5.8%; Average loss: 3.1406
# Iteration: 234; Percent complete: 5.9%; Average loss: 2.8562
# Iteration: 235; Percent complete: 5.9%; Average loss: 2.5947
# Iteration: 236; Percent complete: 5.9%; Average loss: 2.8193
# Iteration: 237; Percent complete: 5.9%; Average loss: 3.1193
# Iteration: 238; Percent complete: 5.9%; Average loss: 2.8843
# Iteration: 239; Percent complete: 6.0%; Average loss: 3.0259
# Iteration: 240; Percent complete: 6.0%; Average loss: 3.1989
# Iteration: 241; Percent complete: 6.0%; Average loss: 3.1880
# Iteration: 242; Percent complete: 6.0%; Average loss: 2.2942
# Iteration: 243; Percent complete: 6.1%; Average loss: 2.5924
# Iteration: 244; Percent complete: 6.1%; Average loss: 2.6865
# Iteration: 245; Percent complete: 6.1%; Average loss: 2.3343
# Iteration: 246; Percent complete: 6.2%; Average loss: 2.5830
# Iteration: 247; Percent complete: 6.2%; Average loss: 2.7066
# Iteration: 248; Percent complete: 6.2%; Average loss: 2.5689
# Iteration: 249; Percent complete: 6.2%; Average loss: 2.7857
# Iteration: 250; Percent complete: 6.2%; Average loss: 2.7953
# Iteration: 251; Percent complete: 6.3%; Average loss: 2.2088
# Iteration: 252; Percent complete: 6.3%; Average loss: 2.5888
# Iteration: 253; Percent complete: 6.3%; Average loss: 2.9457
# Iteration: 254; Percent complete: 6.3%; Average loss: 2.9417
# Iteration: 255; Percent complete: 6.4%; Average loss: 3.1618
# Iteration: 256; Percent complete: 6.4%; Average loss: 2.3911
# Iteration: 257; Percent complete: 6.4%; Average loss: 2.7647
# Iteration: 258; Percent complete: 6.5%; Average loss: 2.6527
# Iteration: 259; Percent complete: 6.5%; Average loss: 3.0715
# Iteration: 260; Percent complete: 6.5%; Average loss: 2.5070
# Iteration: 261; Percent complete: 6.5%; Average loss: 2.1540
# Iteration: 262; Percent complete: 6.6%; Average loss: 3.1779
# Iteration: 263; Percent complete: 6.6%; Average loss: 2.6027
# Iteration: 264; Percent complete: 6.6%; Average loss: 2.3746
# Iteration: 265; Percent complete: 6.6%; Average loss: 2.7997
# Iteration: 266; Percent complete: 6.7%; Average loss: 2.5545
# Iteration: 267; Percent complete: 6.7%; Average loss: 2.9211
# Iteration: 268; Percent complete: 6.7%; Average loss: 2.8540
# Iteration: 269; Percent complete: 6.7%; Average loss: 3.2305
# Iteration: 270; Percent complete: 6.8%; Average loss: 2.6509
# Iteration: 271; Percent complete: 6.8%; Average loss: 2.0130
# Iteration: 272; Percent complete: 6.8%; Average loss: 2.4977
# Iteration: 273; Percent complete: 6.8%; Average loss: 2.8474
# Iteration: 274; Percent complete: 6.9%; Average loss: 2.9449
# Iteration: 275; Percent complete: 6.9%; Average loss: 2.7137
# Iteration: 276; Percent complete: 6.9%; Average loss: 2.9385
# Iteration: 277; Percent complete: 6.9%; Average loss: 2.6899
# Iteration: 278; Percent complete: 7.0%; Average loss: 2.4971
# Iteration: 279; Percent complete: 7.0%; Average loss: 2.9696
# Iteration: 280; Percent complete: 7.0%; Average loss: 2.8222
# Iteration: 281; Percent complete: 7.0%; Average loss: 2.8124
# Iteration: 282; Percent complete: 7.0%; Average loss: 1.8767
# Iteration: 283; Percent complete: 7.1%; Average loss: 3.0728
# Iteration: 284; Percent complete: 7.1%; Average loss: 2.6926
# Iteration: 285; Percent complete: 7.1%; Average loss: 2.6865
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.2093
# Iteration: 287; Percent complete: 7.2%; Average loss: 2.5336
# Iteration: 288; Percent complete: 7.2%; Average loss: 2.5535
# Iteration: 289; Percent complete: 7.2%; Average loss: 2.6674
# Iteration: 290; Percent complete: 7.2%; Average loss: 2.7291
# Iteration: 291; Percent complete: 7.3%; Average loss: 3.1419
# Iteration: 292; Percent complete: 7.3%; Average loss: 2.1616
# Iteration: 293; Percent complete: 7.3%; Average loss: 2.4694
# Iteration: 294; Percent complete: 7.3%; Average loss: 2.5531
# Iteration: 295; Percent complete: 7.4%; Average loss: 2.8557
# Iteration: 296; Percent complete: 7.4%; Average loss: 2.3800
# Iteration: 297; Percent complete: 7.4%; Average loss: 2.0101
# Iteration: 298; Percent complete: 7.4%; Average loss: 3.4156
# Iteration: 299; Percent complete: 7.5%; Average loss: 2.8149
# Iteration: 300; Percent complete: 7.5%; Average loss: 2.6169
# Iteration: 301; Percent complete: 7.5%; Average loss: 2.5256
# Iteration: 302; Percent complete: 7.5%; Average loss: 2.4418
# Iteration: 303; Percent complete: 7.6%; Average loss: 3.4007
# Iteration: 304; Percent complete: 7.6%; Average loss: 2.1327
# Iteration: 305; Percent complete: 7.6%; Average loss: 2.6598
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.1583
# Iteration: 307; Percent complete: 7.7%; Average loss: 2.7557
# Iteration: 308; Percent complete: 7.7%; Average loss: 2.4908
# Iteration: 309; Percent complete: 7.7%; Average loss: 2.5420
# Iteration: 310; Percent complete: 7.8%; Average loss: 2.6410
# Iteration: 311; Percent complete: 7.8%; Average loss: 2.5329
# Iteration: 312; Percent complete: 7.8%; Average loss: 2.6916
# Iteration: 313; Percent complete: 7.8%; Average loss: 2.1295
# Iteration: 314; Percent complete: 7.8%; Average loss: 2.8119
# Iteration: 315; Percent complete: 7.9%; Average loss: 2.3348
# Iteration: 316; Percent complete: 7.9%; Average loss: 2.3378
# Iteration: 317; Percent complete: 7.9%; Average loss: 2.1003
# Iteration: 318; Percent complete: 8.0%; Average loss: 2.9070
# Iteration: 319; Percent complete: 8.0%; Average loss: 2.5774
# Iteration: 320; Percent complete: 8.0%; Average loss: 2.9098
# Iteration: 321; Percent complete: 8.0%; Average loss: 2.0914
# Iteration: 322; Percent complete: 8.1%; Average loss: 3.1596
# Iteration: 323; Percent complete: 8.1%; Average loss: 2.7968
# Iteration: 324; Percent complete: 8.1%; Average loss: 2.6705
# Iteration: 325; Percent complete: 8.1%; Average loss: 2.2897
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.0611
# Iteration: 327; Percent complete: 8.2%; Average loss: 2.2832
# Iteration: 328; Percent complete: 8.2%; Average loss: 2.3794
# Iteration: 329; Percent complete: 8.2%; Average loss: 2.4082
# Iteration: 330; Percent complete: 8.2%; Average loss: 2.9612
# Iteration: 331; Percent complete: 8.3%; Average loss: 2.9651
# Iteration: 332; Percent complete: 8.3%; Average loss: 2.5715
# Iteration: 333; Percent complete: 8.3%; Average loss: 2.9321
# Iteration: 334; Percent complete: 8.3%; Average loss: 2.8184
# Iteration: 335; Percent complete: 8.4%; Average loss: 2.8430
# Iteration: 336; Percent complete: 8.4%; Average loss: 2.2963
# Iteration: 337; Percent complete: 8.4%; Average loss: 2.5021
# Iteration: 338; Percent complete: 8.5%; Average loss: 2.8277
# Iteration: 339; Percent complete: 8.5%; Average loss: 2.0956
# Iteration: 340; Percent complete: 8.5%; Average loss: 2.4041
# Iteration: 341; Percent complete: 8.5%; Average loss: 2.8408
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.0126
# Iteration: 343; Percent complete: 8.6%; Average loss: 2.6295
# Iteration: 344; Percent complete: 8.6%; Average loss: 2.8670
# Iteration: 345; Percent complete: 8.6%; Average loss: 2.4442
# Iteration: 346; Percent complete: 8.6%; Average loss: 2.5969
# Iteration: 347; Percent complete: 8.7%; Average loss: 2.5425
# Iteration: 348; Percent complete: 8.7%; Average loss: 2.0552
# Iteration: 349; Percent complete: 8.7%; Average loss: 2.3869
# Iteration: 350; Percent complete: 8.8%; Average loss: 2.6383
# Iteration: 351; Percent complete: 8.8%; Average loss: 2.6943
# Iteration: 352; Percent complete: 8.8%; Average loss: 2.8373
# Iteration: 353; Percent complete: 8.8%; Average loss: 2.9624
# Iteration: 354; Percent complete: 8.8%; Average loss: 2.4777
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.1215
# Iteration: 356; Percent complete: 8.9%; Average loss: 2.4800
# Iteration: 357; Percent complete: 8.9%; Average loss: 2.8314
# Iteration: 358; Percent complete: 8.9%; Average loss: 2.7467
# Iteration: 359; Percent complete: 9.0%; Average loss: 2.7586
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.1158
# Iteration: 361; Percent complete: 9.0%; Average loss: 1.9000
# Iteration: 362; Percent complete: 9.0%; Average loss: 2.6611
# Iteration: 363; Percent complete: 9.1%; Average loss: 2.8076
# Iteration: 364; Percent complete: 9.1%; Average loss: 2.6121
# Iteration: 365; Percent complete: 9.1%; Average loss: 2.1281
# Iteration: 366; Percent complete: 9.2%; Average loss: 1.9752
# Iteration: 367; Percent complete: 9.2%; Average loss: 2.4460
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.1191
# Iteration: 369; Percent complete: 9.2%; Average loss: 3.0544
# Iteration: 370; Percent complete: 9.2%; Average loss: 2.2172
# Iteration: 371; Percent complete: 9.3%; Average loss: 2.4962
# Iteration: 372; Percent complete: 9.3%; Average loss: 2.2123
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.1795
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.3150
# Iteration: 375; Percent complete: 9.4%; Average loss: 2.9063
# Iteration: 376; Percent complete: 9.4%; Average loss: 2.6353
# Iteration: 377; Percent complete: 9.4%; Average loss: 2.2278
# Iteration: 378; Percent complete: 9.4%; Average loss: 2.4517
# Iteration: 379; Percent complete: 9.5%; Average loss: 2.0703
# Iteration: 380; Percent complete: 9.5%; Average loss: 2.9151
# Iteration: 381; Percent complete: 9.5%; Average loss: 2.4211
# Iteration: 382; Percent complete: 9.6%; Average loss: 2.5722
# Iteration: 383; Percent complete: 9.6%; Average loss: 2.5456
# Iteration: 384; Percent complete: 9.6%; Average loss: 1.9708
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.1205
# Iteration: 386; Percent complete: 9.7%; Average loss: 2.3248
# Iteration: 387; Percent complete: 9.7%; Average loss: 2.6439
# Iteration: 388; Percent complete: 9.7%; Average loss: 2.3232
# Iteration: 389; Percent complete: 9.7%; Average loss: 2.6116
# Iteration: 390; Percent complete: 9.8%; Average loss: 2.6985
# Iteration: 391; Percent complete: 9.8%; Average loss: 2.8889
# Iteration: 392; Percent complete: 9.8%; Average loss: 2.7835
# Iteration: 393; Percent complete: 9.8%; Average loss: 2.6408
# Iteration: 394; Percent complete: 9.8%; Average loss: 2.7874
# Iteration: 395; Percent complete: 9.9%; Average loss: 2.7305
# Iteration: 396; Percent complete: 9.9%; Average loss: 2.3733
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.1727
# Iteration: 398; Percent complete: 10.0%; Average loss: 2.2599
# Iteration: 399; Percent complete: 10.0%; Average loss: 2.0208
# Iteration: 400; Percent complete: 10.0%; Average loss: 2.7168
# Iteration: 401; Percent complete: 10.0%; Average loss: 2.2686
# Iteration: 402; Percent complete: 10.1%; Average loss: 2.9380
# Iteration: 403; Percent complete: 10.1%; Average loss: 2.8481
# Iteration: 404; Percent complete: 10.1%; Average loss: 2.7103
# Iteration: 405; Percent complete: 10.1%; Average loss: 2.7115
# Iteration: 406; Percent complete: 10.2%; Average loss: 2.4369
# Iteration: 407; Percent complete: 10.2%; Average loss: 2.6623
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.0051
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.0222
# Iteration: 410; Percent complete: 10.2%; Average loss: 2.7496
# Iteration: 411; Percent complete: 10.3%; Average loss: 2.5764
# Iteration: 412; Percent complete: 10.3%; Average loss: 2.6940
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.0363
# Iteration: 414; Percent complete: 10.3%; Average loss: 2.7472
# Iteration: 415; Percent complete: 10.4%; Average loss: 2.4031
# Iteration: 416; Percent complete: 10.4%; Average loss: 2.0378
# Iteration: 417; Percent complete: 10.4%; Average loss: 1.9621
# Iteration: 418; Percent complete: 10.4%; Average loss: 2.3539
# Iteration: 419; Percent complete: 10.5%; Average loss: 2.3305
# Iteration: 420; Percent complete: 10.5%; Average loss: 2.8075
# Iteration: 421; Percent complete: 10.5%; Average loss: 2.3169
# Iteration: 422; Percent complete: 10.5%; Average loss: 2.4026
# Iteration: 423; Percent complete: 10.6%; Average loss: 2.5190
# Iteration: 424; Percent complete: 10.6%; Average loss: 2.4371
# Iteration: 425; Percent complete: 10.6%; Average loss: 2.8948
# Iteration: 426; Percent complete: 10.7%; Average loss: 2.2980
# Iteration: 427; Percent complete: 10.7%; Average loss: 2.2390
# Iteration: 428; Percent complete: 10.7%; Average loss: 2.7916
# Iteration: 429; Percent complete: 10.7%; Average loss: 2.3455
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.3210
# Iteration: 431; Percent complete: 10.8%; Average loss: 2.2051
# Iteration: 432; Percent complete: 10.8%; Average loss: 2.5696
# Iteration: 433; Percent complete: 10.8%; Average loss: 2.3883
# Iteration: 434; Percent complete: 10.8%; Average loss: 2.7362
# Iteration: 435; Percent complete: 10.9%; Average loss: 2.0086
# Iteration: 436; Percent complete: 10.9%; Average loss: 2.3147
# Iteration: 437; Percent complete: 10.9%; Average loss: 2.3679
# Iteration: 438; Percent complete: 10.9%; Average loss: 2.8196
# Iteration: 439; Percent complete: 11.0%; Average loss: 2.1965
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.2398
# Iteration: 441; Percent complete: 11.0%; Average loss: 2.3718
# Iteration: 442; Percent complete: 11.1%; Average loss: 2.6578
# Iteration: 443; Percent complete: 11.1%; Average loss: 2.5477
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.0181
# Iteration: 445; Percent complete: 11.1%; Average loss: 2.4426
# Iteration: 446; Percent complete: 11.2%; Average loss: 2.6760
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.2412
# Iteration: 448; Percent complete: 11.2%; Average loss: 2.4147
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.0422
# Iteration: 450; Percent complete: 11.2%; Average loss: 2.8184
# Iteration: 451; Percent complete: 11.3%; Average loss: 2.4474
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.0394
# Iteration: 453; Percent complete: 11.3%; Average loss: 2.2101
# Iteration: 454; Percent complete: 11.3%; Average loss: 1.9509
# Iteration: 455; Percent complete: 11.4%; Average loss: 2.4953
# Iteration: 456; Percent complete: 11.4%; Average loss: 2.7983
# Iteration: 457; Percent complete: 11.4%; Average loss: 2.1064
# Iteration: 458; Percent complete: 11.5%; Average loss: 2.7668
# Iteration: 459; Percent complete: 11.5%; Average loss: 2.4288
# Iteration: 460; Percent complete: 11.5%; Average loss: 2.1276
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.2404
# Iteration: 462; Percent complete: 11.6%; Average loss: 2.1557
# Iteration: 463; Percent complete: 11.6%; Average loss: 2.8607
# Iteration: 464; Percent complete: 11.6%; Average loss: 2.6234
# Iteration: 465; Percent complete: 11.6%; Average loss: 2.7447
# Iteration: 466; Percent complete: 11.7%; Average loss: 2.8458
# Iteration: 467; Percent complete: 11.7%; Average loss: 2.4843
# Iteration: 468; Percent complete: 11.7%; Average loss: 2.7984
# Iteration: 469; Percent complete: 11.7%; Average loss: 2.3900
# Iteration: 470; Percent complete: 11.8%; Average loss: 2.3992
# Iteration: 471; Percent complete: 11.8%; Average loss: 2.7292
# Iteration: 472; Percent complete: 11.8%; Average loss: 2.2439
# Iteration: 473; Percent complete: 11.8%; Average loss: 2.7087
# Iteration: 474; Percent complete: 11.8%; Average loss: 2.4801
# Iteration: 475; Percent complete: 11.9%; Average loss: 2.7381
# Iteration: 476; Percent complete: 11.9%; Average loss: 2.3293
# Iteration: 477; Percent complete: 11.9%; Average loss: 2.2316
# Iteration: 478; Percent complete: 11.9%; Average loss: 2.7193
# Iteration: 479; Percent complete: 12.0%; Average loss: 2.2461
# Iteration: 480; Percent complete: 12.0%; Average loss: 2.0139
# Iteration: 481; Percent complete: 12.0%; Average loss: 2.8100
# Iteration: 482; Percent complete: 12.0%; Average loss: 2.0480
# Iteration: 483; Percent complete: 12.1%; Average loss: 2.5107
# Iteration: 484; Percent complete: 12.1%; Average loss: 2.6065
# Iteration: 485; Percent complete: 12.1%; Average loss: 2.9124
# Iteration: 486; Percent complete: 12.2%; Average loss: 2.3585
# Iteration: 487; Percent complete: 12.2%; Average loss: 2.6231
# Iteration: 488; Percent complete: 12.2%; Average loss: 2.5926
# Iteration: 489; Percent complete: 12.2%; Average loss: 2.9092
# Iteration: 490; Percent complete: 12.2%; Average loss: 2.7987
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.1389
# Iteration: 492; Percent complete: 12.3%; Average loss: 2.3242
# Iteration: 493; Percent complete: 12.3%; Average loss: 2.4569
# Iteration: 494; Percent complete: 12.3%; Average loss: 2.4124
# Iteration: 495; Percent complete: 12.4%; Average loss: 2.2424
# Iteration: 496; Percent complete: 12.4%; Average loss: 2.4643
# Iteration: 497; Percent complete: 12.4%; Average loss: 2.9222
# Iteration: 498; Percent complete: 12.4%; Average loss: 2.5384
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.1619
# Iteration: 500; Percent complete: 12.5%; Average loss: 2.7234
# Iteration: 501; Percent complete: 12.5%; Average loss: 2.4866
# Iteration: 502; Percent complete: 12.6%; Average loss: 2.3241
# Iteration: 503; Percent complete: 12.6%; Average loss: 2.8237
# Iteration: 504; Percent complete: 12.6%; Average loss: 2.7007
# Iteration: 505; Percent complete: 12.6%; Average loss: 2.1159
# Iteration: 506; Percent complete: 12.7%; Average loss: 2.5183
# Iteration: 507; Percent complete: 12.7%; Average loss: 2.3018
# Iteration: 508; Percent complete: 12.7%; Average loss: 2.2157
# Iteration: 509; Percent complete: 12.7%; Average loss: 2.3820
# Iteration: 510; Percent complete: 12.8%; Average loss: 2.7588
# Iteration: 511; Percent complete: 12.8%; Average loss: 2.3181
# Iteration: 512; Percent complete: 12.8%; Average loss: 2.8613
# Iteration: 513; Percent complete: 12.8%; Average loss: 1.9191
# Iteration: 514; Percent complete: 12.8%; Average loss: 2.3968
# Iteration: 515; Percent complete: 12.9%; Average loss: 2.3321
# Iteration: 516; Percent complete: 12.9%; Average loss: 2.6411
# Iteration: 517; Percent complete: 12.9%; Average loss: 2.8581
# Iteration: 518; Percent complete: 13.0%; Average loss: 2.7559
# Iteration: 519; Percent complete: 13.0%; Average loss: 2.6245
# Iteration: 520; Percent complete: 13.0%; Average loss: 2.4751
# Iteration: 521; Percent complete: 13.0%; Average loss: 2.3498
# Iteration: 522; Percent complete: 13.1%; Average loss: 2.7362
# Iteration: 523; Percent complete: 13.1%; Average loss: 2.5399
# Iteration: 524; Percent complete: 13.1%; Average loss: 3.0419
# Iteration: 525; Percent complete: 13.1%; Average loss: 1.9487
# Iteration: 526; Percent complete: 13.2%; Average loss: 2.4069
# Iteration: 527; Percent complete: 13.2%; Average loss: 2.8165
# Iteration: 528; Percent complete: 13.2%; Average loss: 2.9150
# Iteration: 529; Percent complete: 13.2%; Average loss: 2.2125
# Iteration: 530; Percent complete: 13.2%; Average loss: 2.3498
# Iteration: 531; Percent complete: 13.3%; Average loss: 2.8234
# Iteration: 532; Percent complete: 13.3%; Average loss: 2.6067
# Iteration: 533; Percent complete: 13.3%; Average loss: 2.3440
# Iteration: 534; Percent complete: 13.4%; Average loss: 2.6671
# Iteration: 535; Percent complete: 13.4%; Average loss: 2.6770
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.3720
# Iteration: 537; Percent complete: 13.4%; Average loss: 2.6623
# Iteration: 538; Percent complete: 13.5%; Average loss: 2.4877
# Iteration: 539; Percent complete: 13.5%; Average loss: 2.4510
# Iteration: 540; Percent complete: 13.5%; Average loss: 2.4633
# Iteration: 541; Percent complete: 13.5%; Average loss: 2.5465
# Iteration: 542; Percent complete: 13.6%; Average loss: 2.8123
# Iteration: 543; Percent complete: 13.6%; Average loss: 2.7458
# Iteration: 544; Percent complete: 13.6%; Average loss: 2.6111
# Iteration: 545; Percent complete: 13.6%; Average loss: 2.2463
# Iteration: 546; Percent complete: 13.7%; Average loss: 2.8127
# Iteration: 547; Percent complete: 13.7%; Average loss: 2.2882
# Iteration: 548; Percent complete: 13.7%; Average loss: 2.2065
# Iteration: 549; Percent complete: 13.7%; Average loss: 1.9546
# Iteration: 550; Percent complete: 13.8%; Average loss: 2.7260
# Iteration: 551; Percent complete: 13.8%; Average loss: 2.1444
# Iteration: 552; Percent complete: 13.8%; Average loss: 2.5634
# Iteration: 553; Percent complete: 13.8%; Average loss: 2.6990
# Iteration: 554; Percent complete: 13.9%; Average loss: 1.8368
# Iteration: 555; Percent complete: 13.9%; Average loss: 2.2852
# Iteration: 556; Percent complete: 13.9%; Average loss: 2.3872
# Iteration: 557; Percent complete: 13.9%; Average loss: 2.4458
# Iteration: 558; Percent complete: 14.0%; Average loss: 2.6757
# Iteration: 559; Percent complete: 14.0%; Average loss: 2.4667
# Iteration: 560; Percent complete: 14.0%; Average loss: 2.6233
# Iteration: 561; Percent complete: 14.0%; Average loss: 2.3116
# Iteration: 562; Percent complete: 14.1%; Average loss: 2.3990
# Iteration: 563; Percent complete: 14.1%; Average loss: 2.6810
# Iteration: 564; Percent complete: 14.1%; Average loss: 2.5437
# Iteration: 565; Percent complete: 14.1%; Average loss: 2.7505
# Iteration: 566; Percent complete: 14.1%; Average loss: 2.0485
# Iteration: 567; Percent complete: 14.2%; Average loss: 2.2040
# Iteration: 568; Percent complete: 14.2%; Average loss: 2.5054
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.0889
# Iteration: 570; Percent complete: 14.2%; Average loss: 2.5085
# Iteration: 571; Percent complete: 14.3%; Average loss: 2.0540
# Iteration: 572; Percent complete: 14.3%; Average loss: 2.9062
# Iteration: 573; Percent complete: 14.3%; Average loss: 2.0532
# Iteration: 574; Percent complete: 14.3%; Average loss: 2.6472
# Iteration: 575; Percent complete: 14.4%; Average loss: 2.4416
# Iteration: 576; Percent complete: 14.4%; Average loss: 1.9773
# Iteration: 577; Percent complete: 14.4%; Average loss: 2.1146
# Iteration: 578; Percent complete: 14.4%; Average loss: 2.3579
# Iteration: 579; Percent complete: 14.5%; Average loss: 2.4563
# Iteration: 580; Percent complete: 14.5%; Average loss: 2.4593
# Iteration: 581; Percent complete: 14.5%; Average loss: 2.6704
# Iteration: 582; Percent complete: 14.5%; Average loss: 2.8907
# Iteration: 583; Percent complete: 14.6%; Average loss: 2.2507
# Iteration: 584; Percent complete: 14.6%; Average loss: 2.4432
# Iteration: 585; Percent complete: 14.6%; Average loss: 2.5991
# Iteration: 586; Percent complete: 14.6%; Average loss: 2.5482
# Iteration: 587; Percent complete: 14.7%; Average loss: 2.6374
# Iteration: 588; Percent complete: 14.7%; Average loss: 2.4113
# Iteration: 589; Percent complete: 14.7%; Average loss: 2.4289
# Iteration: 590; Percent complete: 14.8%; Average loss: 2.2217
# Iteration: 591; Percent complete: 14.8%; Average loss: 2.4175
# Iteration: 592; Percent complete: 14.8%; Average loss: 2.4401
# Iteration: 593; Percent complete: 14.8%; Average loss: 2.8944
# Iteration: 594; Percent complete: 14.8%; Average loss: 2.6546
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.0747
# Iteration: 596; Percent complete: 14.9%; Average loss: 2.4136
# Iteration: 597; Percent complete: 14.9%; Average loss: 2.7014
# Iteration: 598; Percent complete: 14.9%; Average loss: 2.4710
# Iteration: 599; Percent complete: 15.0%; Average loss: 2.6620
# Iteration: 600; Percent complete: 15.0%; Average loss: 2.6526
# Iteration: 601; Percent complete: 15.0%; Average loss: 2.5162
# Iteration: 602; Percent complete: 15.0%; Average loss: 2.5028
# Iteration: 603; Percent complete: 15.1%; Average loss: 2.3373
# Iteration: 604; Percent complete: 15.1%; Average loss: 2.4993
# Iteration: 605; Percent complete: 15.1%; Average loss: 1.9072
# Iteration: 606; Percent complete: 15.2%; Average loss: 2.7712
# Iteration: 607; Percent complete: 15.2%; Average loss: 2.7858
# Iteration: 608; Percent complete: 15.2%; Average loss: 2.4577
# Iteration: 609; Percent complete: 15.2%; Average loss: 2.5496
# Iteration: 610; Percent complete: 15.2%; Average loss: 2.1187
# Iteration: 611; Percent complete: 15.3%; Average loss: 2.4489
# Iteration: 612; Percent complete: 15.3%; Average loss: 2.4956
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.0581
# Iteration: 614; Percent complete: 15.3%; Average loss: 2.6332
# Iteration: 615; Percent complete: 15.4%; Average loss: 2.7630
# Iteration: 616; Percent complete: 15.4%; Average loss: 2.2953
# Iteration: 617; Percent complete: 15.4%; Average loss: 2.9305
# Iteration: 618; Percent complete: 15.4%; Average loss: 2.2378
# Iteration: 619; Percent complete: 15.5%; Average loss: 2.5997
# Iteration: 620; Percent complete: 15.5%; Average loss: 2.4158
# Iteration: 621; Percent complete: 15.5%; Average loss: 2.4284
# Iteration: 622; Percent complete: 15.6%; Average loss: 2.2538
# Iteration: 623; Percent complete: 15.6%; Average loss: 2.5399
# Iteration: 624; Percent complete: 15.6%; Average loss: 2.7777
# Iteration: 625; Percent complete: 15.6%; Average loss: 2.5151
# Iteration: 626; Percent complete: 15.7%; Average loss: 2.9881
# Iteration: 627; Percent complete: 15.7%; Average loss: 2.7584
# Iteration: 628; Percent complete: 15.7%; Average loss: 2.2049
# Iteration: 629; Percent complete: 15.7%; Average loss: 2.2193
# Iteration: 630; Percent complete: 15.8%; Average loss: 2.5285
# Iteration: 631; Percent complete: 15.8%; Average loss: 1.7950
# Iteration: 632; Percent complete: 15.8%; Average loss: 2.0339
# Iteration: 633; Percent complete: 15.8%; Average loss: 2.8172
# Iteration: 634; Percent complete: 15.8%; Average loss: 2.0894
# Iteration: 635; Percent complete: 15.9%; Average loss: 2.7113
# Iteration: 636; Percent complete: 15.9%; Average loss: 2.6458
# Iteration: 637; Percent complete: 15.9%; Average loss: 2.1396
# Iteration: 638; Percent complete: 16.0%; Average loss: 2.3535
# Iteration: 639; Percent complete: 16.0%; Average loss: 2.4110
# Iteration: 640; Percent complete: 16.0%; Average loss: 2.1100
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.0668
# Iteration: 642; Percent complete: 16.1%; Average loss: 2.3874
# Iteration: 643; Percent complete: 16.1%; Average loss: 2.7986
# Iteration: 644; Percent complete: 16.1%; Average loss: 2.6648
# Iteration: 645; Percent complete: 16.1%; Average loss: 2.5226
# Iteration: 646; Percent complete: 16.2%; Average loss: 2.2417
# Iteration: 647; Percent complete: 16.2%; Average loss: 2.5221
# Iteration: 648; Percent complete: 16.2%; Average loss: 2.3266
# Iteration: 649; Percent complete: 16.2%; Average loss: 2.8945
# Iteration: 650; Percent complete: 16.2%; Average loss: 2.8565
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.0150
# Iteration: 652; Percent complete: 16.3%; Average loss: 1.9145
# Iteration: 653; Percent complete: 16.3%; Average loss: 2.5376
# Iteration: 654; Percent complete: 16.4%; Average loss: 2.4130
# Iteration: 655; Percent complete: 16.4%; Average loss: 1.9918
# Iteration: 656; Percent complete: 16.4%; Average loss: 2.0804
# Iteration: 657; Percent complete: 16.4%; Average loss: 2.4264
# Iteration: 658; Percent complete: 16.4%; Average loss: 2.7829
# Iteration: 659; Percent complete: 16.5%; Average loss: 2.6847
# Iteration: 660; Percent complete: 16.5%; Average loss: 2.5490
# Iteration: 661; Percent complete: 16.5%; Average loss: 2.7156
# Iteration: 662; Percent complete: 16.6%; Average loss: 2.7417
# Iteration: 663; Percent complete: 16.6%; Average loss: 1.7962
# Iteration: 664; Percent complete: 16.6%; Average loss: 2.4100
# Iteration: 665; Percent complete: 16.6%; Average loss: 1.9874
# Iteration: 666; Percent complete: 16.7%; Average loss: 2.2852
# Iteration: 667; Percent complete: 16.7%; Average loss: 2.4228
# Iteration: 668; Percent complete: 16.7%; Average loss: 2.9165
# Iteration: 669; Percent complete: 16.7%; Average loss: 2.3291
# Iteration: 670; Percent complete: 16.8%; Average loss: 2.9235
# Iteration: 671; Percent complete: 16.8%; Average loss: 1.9720
# Iteration: 672; Percent complete: 16.8%; Average loss: 2.8911
# Iteration: 673; Percent complete: 16.8%; Average loss: 2.6595
# Iteration: 674; Percent complete: 16.9%; Average loss: 2.4952
# Iteration: 675; Percent complete: 16.9%; Average loss: 2.0774
# Iteration: 676; Percent complete: 16.9%; Average loss: 2.6095
# Iteration: 677; Percent complete: 16.9%; Average loss: 2.3678
# Iteration: 678; Percent complete: 17.0%; Average loss: 2.3654
# Iteration: 679; Percent complete: 17.0%; Average loss: 2.9288
# Iteration: 680; Percent complete: 17.0%; Average loss: 2.8867
# Iteration: 681; Percent complete: 17.0%; Average loss: 2.0310
# Iteration: 682; Percent complete: 17.1%; Average loss: 2.1220
# Iteration: 683; Percent complete: 17.1%; Average loss: 2.7301
# Iteration: 684; Percent complete: 17.1%; Average loss: 2.2721
# Iteration: 685; Percent complete: 17.1%; Average loss: 1.8873
# Iteration: 686; Percent complete: 17.2%; Average loss: 2.2697
# Iteration: 687; Percent complete: 17.2%; Average loss: 2.1961
# Iteration: 688; Percent complete: 17.2%; Average loss: 2.8476
# Iteration: 689; Percent complete: 17.2%; Average loss: 2.8784
# Iteration: 690; Percent complete: 17.2%; Average loss: 2.6099
# Iteration: 691; Percent complete: 17.3%; Average loss: 2.9350
# Iteration: 692; Percent complete: 17.3%; Average loss: 2.2959
# Iteration: 693; Percent complete: 17.3%; Average loss: 2.3396
# Iteration: 694; Percent complete: 17.3%; Average loss: 1.9540
# Iteration: 695; Percent complete: 17.4%; Average loss: 2.9241
# Iteration: 696; Percent complete: 17.4%; Average loss: 2.5321
# Iteration: 697; Percent complete: 17.4%; Average loss: 2.6262
# Iteration: 698; Percent complete: 17.4%; Average loss: 2.0311
# Iteration: 699; Percent complete: 17.5%; Average loss: 2.3911
# Iteration: 700; Percent complete: 17.5%; Average loss: 2.0994
# Iteration: 701; Percent complete: 17.5%; Average loss: 2.3182
# Iteration: 702; Percent complete: 17.5%; Average loss: 2.1807
# Iteration: 703; Percent complete: 17.6%; Average loss: 2.6329
# Iteration: 704; Percent complete: 17.6%; Average loss: 2.2083
# Iteration: 705; Percent complete: 17.6%; Average loss: 2.2256
# Iteration: 706; Percent complete: 17.6%; Average loss: 2.3878
# Iteration: 707; Percent complete: 17.7%; Average loss: 2.8283
# Iteration: 708; Percent complete: 17.7%; Average loss: 2.6531
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.0150
# Iteration: 710; Percent complete: 17.8%; Average loss: 2.8453
# Iteration: 711; Percent complete: 17.8%; Average loss: 1.9498
# Iteration: 712; Percent complete: 17.8%; Average loss: 2.2360
# Iteration: 713; Percent complete: 17.8%; Average loss: 2.0207
# Iteration: 714; Percent complete: 17.8%; Average loss: 2.2058
# Iteration: 715; Percent complete: 17.9%; Average loss: 2.6715
# Iteration: 716; Percent complete: 17.9%; Average loss: 2.2311
# Iteration: 717; Percent complete: 17.9%; Average loss: 2.1826
# Iteration: 718; Percent complete: 17.9%; Average loss: 2.0927
# Iteration: 719; Percent complete: 18.0%; Average loss: 2.7352
# Iteration: 720; Percent complete: 18.0%; Average loss: 2.7100
# Iteration: 721; Percent complete: 18.0%; Average loss: 2.9080
# Iteration: 722; Percent complete: 18.1%; Average loss: 2.4454
# Iteration: 723; Percent complete: 18.1%; Average loss: 2.9091
# Iteration: 724; Percent complete: 18.1%; Average loss: 2.5069
# Iteration: 725; Percent complete: 18.1%; Average loss: 2.0054
# Iteration: 726; Percent complete: 18.1%; Average loss: 2.2487
# Iteration: 727; Percent complete: 18.2%; Average loss: 2.6778
# Iteration: 728; Percent complete: 18.2%; Average loss: 2.5728
# Iteration: 729; Percent complete: 18.2%; Average loss: 2.4181
# Iteration: 730; Percent complete: 18.2%; Average loss: 2.5514
# Iteration: 731; Percent complete: 18.3%; Average loss: 2.1917
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.0294
# Iteration: 733; Percent complete: 18.3%; Average loss: 2.3205
# Iteration: 734; Percent complete: 18.4%; Average loss: 2.7639
# Iteration: 735; Percent complete: 18.4%; Average loss: 2.4252
# Iteration: 736; Percent complete: 18.4%; Average loss: 2.8070
# Iteration: 737; Percent complete: 18.4%; Average loss: 1.6980
# Iteration: 738; Percent complete: 18.4%; Average loss: 2.2368
# Iteration: 739; Percent complete: 18.5%; Average loss: 1.8444
# Iteration: 740; Percent complete: 18.5%; Average loss: 2.4357
# Iteration: 741; Percent complete: 18.5%; Average loss: 1.8334
# Iteration: 742; Percent complete: 18.6%; Average loss: 2.0513
# Iteration: 743; Percent complete: 18.6%; Average loss: 2.4944
# Iteration: 744; Percent complete: 18.6%; Average loss: 2.6935
# Iteration: 745; Percent complete: 18.6%; Average loss: 2.9155
# Iteration: 746; Percent complete: 18.6%; Average loss: 2.3821
# Iteration: 747; Percent complete: 18.7%; Average loss: 2.6546
# Iteration: 748; Percent complete: 18.7%; Average loss: 1.9500
# Iteration: 749; Percent complete: 18.7%; Average loss: 2.4085
# Iteration: 750; Percent complete: 18.8%; Average loss: 2.3029
# Iteration: 751; Percent complete: 18.8%; Average loss: 2.9722
# Iteration: 752; Percent complete: 18.8%; Average loss: 1.9827
# Iteration: 753; Percent complete: 18.8%; Average loss: 2.7351
# Iteration: 754; Percent complete: 18.9%; Average loss: 2.4245
# Iteration: 755; Percent complete: 18.9%; Average loss: 2.2000
# Iteration: 756; Percent complete: 18.9%; Average loss: 2.6888
# Iteration: 757; Percent complete: 18.9%; Average loss: 2.4508
# Iteration: 758; Percent complete: 18.9%; Average loss: 2.6240
# Iteration: 759; Percent complete: 19.0%; Average loss: 2.5440
# Iteration: 760; Percent complete: 19.0%; Average loss: 1.8344
# Iteration: 761; Percent complete: 19.0%; Average loss: 2.3698
# Iteration: 762; Percent complete: 19.1%; Average loss: 2.2194
# Iteration: 763; Percent complete: 19.1%; Average loss: 2.0983
# Iteration: 764; Percent complete: 19.1%; Average loss: 1.6440
# Iteration: 765; Percent complete: 19.1%; Average loss: 2.1550
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.1424
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.1526
# Iteration: 768; Percent complete: 19.2%; Average loss: 1.9958
# Iteration: 769; Percent complete: 19.2%; Average loss: 2.6866
# Iteration: 770; Percent complete: 19.2%; Average loss: 2.4480
# Iteration: 771; Percent complete: 19.3%; Average loss: 2.3627
# Iteration: 772; Percent complete: 19.3%; Average loss: 2.6030
# Iteration: 773; Percent complete: 19.3%; Average loss: 2.1879
# Iteration: 774; Percent complete: 19.4%; Average loss: 2.7505
# Iteration: 775; Percent complete: 19.4%; Average loss: 2.6992
# Iteration: 776; Percent complete: 19.4%; Average loss: 2.2334
# Iteration: 777; Percent complete: 19.4%; Average loss: 2.5567
# Iteration: 778; Percent complete: 19.4%; Average loss: 2.1974
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.1645
# Iteration: 780; Percent complete: 19.5%; Average loss: 2.5983
# Iteration: 781; Percent complete: 19.5%; Average loss: 2.5027
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 1.5277
# Iteration: 3749; Percent complete: 93.7%; Average loss: 1.4535
# Iteration: 3750; Percent complete: 93.8%; Average loss: 1.5460
# Iteration: 3751; Percent complete: 93.8%; Average loss: 1.4013
# Iteration: 3752; Percent complete: 93.8%; Average loss: 1.5724
# Iteration: 3753; Percent complete: 93.8%; Average loss: 1.9145
# Iteration: 3754; Percent complete: 93.8%; Average loss: 1.8435
# Iteration: 3755; Percent complete: 93.9%; Average loss: 1.4246
# Iteration: 3756; Percent complete: 93.9%; Average loss: 1.9358
# Iteration: 3757; Percent complete: 93.9%; Average loss: 1.7898
# Iteration: 3758; Percent complete: 94.0%; Average loss: 2.0654
# Iteration: 3759; Percent complete: 94.0%; Average loss: 1.9699
# Iteration: 3760; Percent complete: 94.0%; Average loss: 1.9059
# Iteration: 3761; Percent complete: 94.0%; Average loss: 1.8519
# Iteration: 3762; Percent complete: 94.0%; Average loss: 1.5392
# Iteration: 3763; Percent complete: 94.1%; Average loss: 1.6319
# Iteration: 3764; Percent complete: 94.1%; Average loss: 1.8687
# Iteration: 3765; Percent complete: 94.1%; Average loss: 1.8027
# Iteration: 3766; Percent complete: 94.2%; Average loss: 1.6898
# Iteration: 3767; Percent complete: 94.2%; Average loss: 1.5044
# Iteration: 3768; Percent complete: 94.2%; Average loss: 1.8783
# Iteration: 3769; Percent complete: 94.2%; Average loss: 1.6320
# Iteration: 3770; Percent complete: 94.2%; Average loss: 1.6167
# Iteration: 3771; Percent complete: 94.3%; Average loss: 2.1739
# Iteration: 3772; Percent complete: 94.3%; Average loss: 1.6817
# Iteration: 3773; Percent complete: 94.3%; Average loss: 1.9162
# Iteration: 3774; Percent complete: 94.3%; Average loss: 1.6892
# Iteration: 3775; Percent complete: 94.4%; Average loss: 1.7905
# Iteration: 3776; Percent complete: 94.4%; Average loss: 1.7231
# Iteration: 3777; Percent complete: 94.4%; Average loss: 1.9443
# Iteration: 3778; Percent complete: 94.5%; Average loss: 1.4696
# Iteration: 3779; Percent complete: 94.5%; Average loss: 1.3393
# Iteration: 3780; Percent complete: 94.5%; Average loss: 1.5794
# Iteration: 3781; Percent complete: 94.5%; Average loss: 1.7742
# Iteration: 3782; Percent complete: 94.5%; Average loss: 1.6709
# Iteration: 3783; Percent complete: 94.6%; Average loss: 1.9339
# Iteration: 3784; Percent complete: 94.6%; Average loss: 1.7205
# Iteration: 3785; Percent complete: 94.6%; Average loss: 1.4286
# Iteration: 3786; Percent complete: 94.7%; Average loss: 1.9334
# Iteration: 3787; Percent complete: 94.7%; Average loss: 1.5373
# Iteration: 3788; Percent complete: 94.7%; Average loss: 1.9117
# Iteration: 3789; Percent complete: 94.7%; Average loss: 1.7662
# Iteration: 3790; Percent complete: 94.8%; Average loss: 1.8161
# Iteration: 3791; Percent complete: 94.8%; Average loss: 1.5870
# Iteration: 3792; Percent complete: 94.8%; Average loss: 1.5207
# Iteration: 3793; Percent complete: 94.8%; Average loss: 1.5187
# Iteration: 3794; Percent complete: 94.8%; Average loss: 1.4951
# Iteration: 3795; Percent complete: 94.9%; Average loss: 1.5681
# Iteration: 3796; Percent complete: 94.9%; Average loss: 1.5283
# Iteration: 3797; Percent complete: 94.9%; Average loss: 1.5488
# Iteration: 3798; Percent complete: 95.0%; Average loss: 1.8662
# Iteration: 3799; Percent complete: 95.0%; Average loss: 1.5690
# Iteration: 3800; Percent complete: 95.0%; Average loss: 1.8015
# Iteration: 3801; Percent complete: 95.0%; Average loss: 1.2731
# Iteration: 3802; Percent complete: 95.0%; Average loss: 1.4973
# Iteration: 3803; Percent complete: 95.1%; Average loss: 1.8270
# Iteration: 3804; Percent complete: 95.1%; Average loss: 1.4687
# Iteration: 3805; Percent complete: 95.1%; Average loss: 1.2802
# Iteration: 3806; Percent complete: 95.2%; Average loss: 1.6893
# Iteration: 3807; Percent complete: 95.2%; Average loss: 1.6987
# Iteration: 3808; Percent complete: 95.2%; Average loss: 1.7903
# Iteration: 3809; Percent complete: 95.2%; Average loss: 1.6024
# Iteration: 3810; Percent complete: 95.2%; Average loss: 1.7031
# Iteration: 3811; Percent complete: 95.3%; Average loss: 1.3824
# Iteration: 3812; Percent complete: 95.3%; Average loss: 1.5714
# Iteration: 3813; Percent complete: 95.3%; Average loss: 1.4813
# Iteration: 3814; Percent complete: 95.3%; Average loss: 2.1400
# Iteration: 3815; Percent complete: 95.4%; Average loss: 1.6239
# Iteration: 3816; Percent complete: 95.4%; Average loss: 1.6257
# Iteration: 3817; Percent complete: 95.4%; Average loss: 2.2731
# Iteration: 3818; Percent complete: 95.5%; Average loss: 1.4264
# Iteration: 3819; Percent complete: 95.5%; Average loss: 1.8136
# Iteration: 3820; Percent complete: 95.5%; Average loss: 1.5378
# Iteration: 3821; Percent complete: 95.5%; Average loss: 1.4978
# Iteration: 3822; Percent complete: 95.5%; Average loss: 1.5765
# Iteration: 3823; Percent complete: 95.6%; Average loss: 1.8155
# Iteration: 3824; Percent complete: 95.6%; Average loss: 1.3846
# Iteration: 3825; Percent complete: 95.6%; Average loss: 1.3493
# Iteration: 3826; Percent complete: 95.7%; Average loss: 1.6502
# Iteration: 3827; Percent complete: 95.7%; Average loss: 1.7598
# Iteration: 3828; Percent complete: 95.7%; Average loss: 1.4128
# Iteration: 3829; Percent complete: 95.7%; Average loss: 1.6765
# Iteration: 3830; Percent complete: 95.8%; Average loss: 1.8625
# Iteration: 3831; Percent complete: 95.8%; Average loss: 1.6464
# Iteration: 3832; Percent complete: 95.8%; Average loss: 2.0751
# Iteration: 3833; Percent complete: 95.8%; Average loss: 1.3622
# Iteration: 3834; Percent complete: 95.9%; Average loss: 1.5158
# Iteration: 3835; Percent complete: 95.9%; Average loss: 1.4397
# Iteration: 3836; Percent complete: 95.9%; Average loss: 1.5099
# Iteration: 3837; Percent complete: 95.9%; Average loss: 1.2905
# Iteration: 3838; Percent complete: 96.0%; Average loss: 1.9878
# Iteration: 3839; Percent complete: 96.0%; Average loss: 1.8048
# Iteration: 3840; Percent complete: 96.0%; Average loss: 1.6790
# Iteration: 3841; Percent complete: 96.0%; Average loss: 1.5004
# Iteration: 3842; Percent complete: 96.0%; Average loss: 1.5866
# Iteration: 3843; Percent complete: 96.1%; Average loss: 1.5960
# Iteration: 3844; Percent complete: 96.1%; Average loss: 2.1436
# Iteration: 3845; Percent complete: 96.1%; Average loss: 1.6306
# Iteration: 3846; Percent complete: 96.2%; Average loss: 2.0016
# Iteration: 3847; Percent complete: 96.2%; Average loss: 1.6737
# Iteration: 3848; Percent complete: 96.2%; Average loss: 1.7753
# Iteration: 3849; Percent complete: 96.2%; Average loss: 1.5321
# Iteration: 3850; Percent complete: 96.2%; Average loss: 1.5692
# Iteration: 3851; Percent complete: 96.3%; Average loss: 1.5992
# Iteration: 3852; Percent complete: 96.3%; Average loss: 2.0215
# Iteration: 3853; Percent complete: 96.3%; Average loss: 1.6604
# Iteration: 3854; Percent complete: 96.4%; Average loss: 1.4968
# Iteration: 3855; Percent complete: 96.4%; Average loss: 1.5568
# Iteration: 3856; Percent complete: 96.4%; Average loss: 1.6937
# Iteration: 3857; Percent complete: 96.4%; Average loss: 1.4142
# Iteration: 3858; Percent complete: 96.5%; Average loss: 1.5209
# Iteration: 3859; Percent complete: 96.5%; Average loss: 1.2432
# Iteration: 3860; Percent complete: 96.5%; Average loss: 1.6129
# Iteration: 3861; Percent complete: 96.5%; Average loss: 1.8276
# Iteration: 3862; Percent complete: 96.5%; Average loss: 1.5814
# Iteration: 3863; Percent complete: 96.6%; Average loss: 2.0852
# Iteration: 3864; Percent complete: 96.6%; Average loss: 1.4094
# Iteration: 3865; Percent complete: 96.6%; Average loss: 1.9503
# Iteration: 3866; Percent complete: 96.7%; Average loss: 1.3153
# Iteration: 3867; Percent complete: 96.7%; Average loss: 1.4118
# Iteration: 3868; Percent complete: 96.7%; Average loss: 1.9462
# Iteration: 3869; Percent complete: 96.7%; Average loss: 1.4129
# Iteration: 3870; Percent complete: 96.8%; Average loss: 1.7897
# Iteration: 3871; Percent complete: 96.8%; Average loss: 2.0393
# Iteration: 3872; Percent complete: 96.8%; Average loss: 1.7479
# Iteration: 3873; Percent complete: 96.8%; Average loss: 1.4250
# Iteration: 3874; Percent complete: 96.9%; Average loss: 1.5819
# Iteration: 3875; Percent complete: 96.9%; Average loss: 1.5506
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.0013
# Iteration: 3877; Percent complete: 96.9%; Average loss: 1.8223
# Iteration: 3878; Percent complete: 97.0%; Average loss: 1.7674
# Iteration: 3879; Percent complete: 97.0%; Average loss: 1.7599
# Iteration: 3880; Percent complete: 97.0%; Average loss: 1.6461
# Iteration: 3881; Percent complete: 97.0%; Average loss: 1.4473
# Iteration: 3882; Percent complete: 97.0%; Average loss: 1.5570
# Iteration: 3883; Percent complete: 97.1%; Average loss: 1.3110
# Iteration: 3884; Percent complete: 97.1%; Average loss: 2.1385
# Iteration: 3885; Percent complete: 97.1%; Average loss: 1.6090
# Iteration: 3886; Percent complete: 97.2%; Average loss: 1.3126
# Iteration: 3887; Percent complete: 97.2%; Average loss: 1.8906
# Iteration: 3888; Percent complete: 97.2%; Average loss: 1.5940
# Iteration: 3889; Percent complete: 97.2%; Average loss: 1.9599
# Iteration: 3890; Percent complete: 97.2%; Average loss: 1.6197
# Iteration: 3891; Percent complete: 97.3%; Average loss: 1.3514
# Iteration: 3892; Percent complete: 97.3%; Average loss: 1.4617
# Iteration: 3893; Percent complete: 97.3%; Average loss: 1.6470
# Iteration: 3894; Percent complete: 97.4%; Average loss: 1.2223
# Iteration: 3895; Percent complete: 97.4%; Average loss: 1.7357
# Iteration: 3896; Percent complete: 97.4%; Average loss: 1.9020
# Iteration: 3897; Percent complete: 97.4%; Average loss: 1.3811
# Iteration: 3898; Percent complete: 97.5%; Average loss: 1.9912
# Iteration: 3899; Percent complete: 97.5%; Average loss: 1.4828
# Iteration: 3900; Percent complete: 97.5%; Average loss: 1.6293
# Iteration: 3901; Percent complete: 97.5%; Average loss: 1.7499
# Iteration: 3902; Percent complete: 97.5%; Average loss: 1.8956
# Iteration: 3903; Percent complete: 97.6%; Average loss: 1.6062
# Iteration: 3904; Percent complete: 97.6%; Average loss: 1.3838
# Iteration: 3905; Percent complete: 97.6%; Average loss: 1.5507
# Iteration: 3906; Percent complete: 97.7%; Average loss: 1.5301
# Iteration: 3907; Percent complete: 97.7%; Average loss: 1.3622
# Iteration: 3908; Percent complete: 97.7%; Average loss: 1.7274
# Iteration: 3909; Percent complete: 97.7%; Average loss: 1.8374
# Iteration: 3910; Percent complete: 97.8%; Average loss: 1.7368
# Iteration: 3911; Percent complete: 97.8%; Average loss: 1.8100
# Iteration: 3912; Percent complete: 97.8%; Average loss: 1.5891
# Iteration: 3913; Percent complete: 97.8%; Average loss: 1.1800
# Iteration: 3914; Percent complete: 97.9%; Average loss: 1.6983
# Iteration: 3915; Percent complete: 97.9%; Average loss: 1.9739
# Iteration: 3916; Percent complete: 97.9%; Average loss: 1.5493
# Iteration: 3917; Percent complete: 97.9%; Average loss: 1.7832
# Iteration: 3918; Percent complete: 98.0%; Average loss: 1.6310
# Iteration: 3919; Percent complete: 98.0%; Average loss: 1.4885
# Iteration: 3920; Percent complete: 98.0%; Average loss: 1.9960
# Iteration: 3921; Percent complete: 98.0%; Average loss: 1.6356
# Iteration: 3922; Percent complete: 98.0%; Average loss: 1.3228
# Iteration: 3923; Percent complete: 98.1%; Average loss: 1.5034
# Iteration: 3924; Percent complete: 98.1%; Average loss: 1.6892
# Iteration: 3925; Percent complete: 98.1%; Average loss: 1.5131
# Iteration: 3926; Percent complete: 98.2%; Average loss: 1.4955
# Iteration: 3927; Percent complete: 98.2%; Average loss: 1.6106
# Iteration: 3928; Percent complete: 98.2%; Average loss: 1.5645
# Iteration: 3929; Percent complete: 98.2%; Average loss: 1.6893
# Iteration: 3930; Percent complete: 98.2%; Average loss: 1.4777
# Iteration: 3931; Percent complete: 98.3%; Average loss: 1.2313
# Iteration: 3932; Percent complete: 98.3%; Average loss: 1.6128
# Iteration: 3933; Percent complete: 98.3%; Average loss: 1.6480
# Iteration: 3934; Percent complete: 98.4%; Average loss: 1.8923
# Iteration: 3935; Percent complete: 98.4%; Average loss: 2.0109
# Iteration: 3936; Percent complete: 98.4%; Average loss: 1.4325
# Iteration: 3937; Percent complete: 98.4%; Average loss: 1.3160
# Iteration: 3938; Percent complete: 98.5%; Average loss: 1.4810
# Iteration: 3939; Percent complete: 98.5%; Average loss: 1.5278
# Iteration: 3940; Percent complete: 98.5%; Average loss: 1.5315
# Iteration: 3941; Percent complete: 98.5%; Average loss: 1.6517
# Iteration: 3942; Percent complete: 98.6%; Average loss: 1.8258
# Iteration: 3943; Percent complete: 98.6%; Average loss: 1.4743
# Iteration: 3944; Percent complete: 98.6%; Average loss: 2.1019
# Iteration: 3945; Percent complete: 98.6%; Average loss: 1.5949
# Iteration: 3946; Percent complete: 98.7%; Average loss: 1.3126
# Iteration: 3947; Percent complete: 98.7%; Average loss: 1.7679
# Iteration: 3948; Percent complete: 98.7%; Average loss: 1.7953
# Iteration: 3949; Percent complete: 98.7%; Average loss: 1.6459
# Iteration: 3950; Percent complete: 98.8%; Average loss: 1.7139
# Iteration: 3951; Percent complete: 98.8%; Average loss: 1.3774
# Iteration: 3952; Percent complete: 98.8%; Average loss: 1.3199
# Iteration: 3953; Percent complete: 98.8%; Average loss: 1.7457
# Iteration: 3954; Percent complete: 98.9%; Average loss: 1.4310
# Iteration: 3955; Percent complete: 98.9%; Average loss: 1.4321
# Iteration: 3956; Percent complete: 98.9%; Average loss: 1.4612
# Iteration: 3957; Percent complete: 98.9%; Average loss: 1.4356
# Iteration: 3958; Percent complete: 99.0%; Average loss: 1.5882
# Iteration: 3959; Percent complete: 99.0%; Average loss: 1.5063
# Iteration: 3960; Percent complete: 99.0%; Average loss: 1.4623
# Iteration: 3961; Percent complete: 99.0%; Average loss: 1.3237
# Iteration: 3962; Percent complete: 99.1%; Average loss: 1.5115
# Iteration: 3963; Percent complete: 99.1%; Average loss: 1.3882
# Iteration: 3964; Percent complete: 99.1%; Average loss: 1.8418
# Iteration: 3965; Percent complete: 99.1%; Average loss: 1.7736
# Iteration: 3966; Percent complete: 99.2%; Average loss: 1.6815
# Iteration: 3967; Percent complete: 99.2%; Average loss: 1.6116
# Iteration: 3968; Percent complete: 99.2%; Average loss: 1.3264
# Iteration: 3969; Percent complete: 99.2%; Average loss: 1.6166
# Iteration: 3970; Percent complete: 99.2%; Average loss: 1.9448
# Iteration: 3971; Percent complete: 99.3%; Average loss: 2.0292
# Iteration: 3972; Percent complete: 99.3%; Average loss: 1.8176
# Iteration: 3973; Percent complete: 99.3%; Average loss: 1.7602
# Iteration: 3974; Percent complete: 99.4%; Average loss: 1.7243
# Iteration: 3975; Percent complete: 99.4%; Average loss: 1.7240
# Iteration: 3976; Percent complete: 99.4%; Average loss: 1.9944
# Iteration: 3977; Percent complete: 99.4%; Average loss: 1.6936
# Iteration: 3978; Percent complete: 99.5%; Average loss: 1.8793
# Iteration: 3979; Percent complete: 99.5%; Average loss: 1.3871
# Iteration: 3980; Percent complete: 99.5%; Average loss: 1.7177
# Iteration: 3981; Percent complete: 99.5%; Average loss: 1.9315
# Iteration: 3982; Percent complete: 99.6%; Average loss: 1.7876
# Iteration: 3983; Percent complete: 99.6%; Average loss: 1.2468
# Iteration: 3984; Percent complete: 99.6%; Average loss: 1.4944
# Iteration: 3985; Percent complete: 99.6%; Average loss: 1.9516
# Iteration: 3986; Percent complete: 99.7%; Average loss: 1.3366
# Iteration: 3987; Percent complete: 99.7%; Average loss: 1.3116
# Iteration: 3988; Percent complete: 99.7%; Average loss: 1.7984
# Iteration: 3989; Percent complete: 99.7%; Average loss: 1.7339
# Iteration: 3990; Percent complete: 99.8%; Average loss: 1.3848
# Iteration: 3991; Percent complete: 99.8%; Average loss: 1.7641
# Iteration: 3992; Percent complete: 99.8%; Average loss: 1.3300
# Iteration: 3993; Percent complete: 99.8%; Average loss: 1.6646
# Iteration: 3994; Percent complete: 99.9%; Average loss: 1.4777
# Iteration: 3995; Percent complete: 99.9%; Average loss: 1.6188
# Iteration: 3996; Percent complete: 99.9%; Average loss: 1.8776
# Iteration: 3997; Percent complete: 99.9%; Average loss: 1.5232
# Iteration: 3998; Percent complete: 100.0%; Average loss: 1.6622
# Iteration: 3999; Percent complete: 100.0%; Average loss: 1.4100
# Iteration: 4000; Percent complete: 100.0%; Average loss: 1.7570

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > She okay?
# Bot: she s fine.
# > What good stuff?
# Bot: i don t know.
# > have fun tonight?
# Bot: i don t know.
# > then that's all you had to say.
# Bot: but i m so sorry.
# > they do to!
# Bot: they re not going to kill her.
# > wow
# Bot: i m sorry.
# > I'm kidding.
# Bot: i m sure you re a friend.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-a79dd57706ac> in <cell line: 9>()
#       7
#       8 # Begin chatting (uncomment and run the following line to begin)
# ----> 9 evaluateInput(encoder, decoder, searcher, voc)
#
# <ipython-input-15-27fa8fc5f566> in evaluateInput(encoder, decoder, searcher, voc)
#      22         try:
#      23             # Get input sentence
# ---> 24             input_sentence = input('> ')
#      25             # Check if it is quit case
#      26             if input_sentence == 'q' or input_sentence == 'quit': break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
